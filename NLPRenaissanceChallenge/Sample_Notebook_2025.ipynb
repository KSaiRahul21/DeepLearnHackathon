# %% [markdown]
# # **RenAIssance: OCR for Seventeenth Century Spanish Texts**
#
# ## **Overview**
# RenAIssance project aims to utilize optical character recognition (OCR) to digitize text sources not yet addressed by current tools. The competition leverages machine learning techniques to enable OCR on various undigitized materials. Specifically, it focuses on AI applications to recognize text in seventeenth-century Spanish printed sources, a niche largely ignored by existing OCR solutions.
#
# Current OCR tools, like Adobe Acrobat’s OCR, struggle with transliteration from historical texts. These tools can recognize text from modern, clearly printed sources but fail with early print forms and manuscripts.
#
# <p align="center">
# <img src="https://github.com/ML4SCI/DeepLearnHackathon/blob/Renaissance/NLPRenaissanceChallenge/images/book_header.png?raw=true">
# </p>
#
# ## **Objective**
# Build and evaluate a model to recognize text in scanned pages from historical Spanish texts. The aim is to improve transcription accuracy on low-resource, early print data that traditional OCR tools cannot handle.
#
# This notebook demonstrates the use of Convolutional-Recurrent Neural Network (CRNN) architectures to solve the problem of Optical Character Recognition (OCR) for seventeenth-century Spanish texts. The model is trained on the given dataset, with transcriptions available for the first 25 pages. The remaining 6 pages are used for testing the model's performance. The goal is to improve the accuracy of the OCR model to achieve good results.
#
# <p align="center">
# <img src="https://github.com/ML4SCI/DeepLearnHackathon/blob/Renaissance/NLPRenaissanceChallenge/images/crnn_architecture.png?raw=true">
# </p>
#
# ## **Dataset**
# We use with two digitized books:
# - Nobleza Virtuosa
# - Noble Perfecto
#
# Each dataset contains:
# - Scanned page images (~31 pages each).
# - Ground truth transcriptions (.docx) for the first 25 pages.
# - Preprocessed bounding boxes aligned to the text for training.
#
# The last 6 pages are reserved for testing (no transcription provided).
#
# Datasets have been preprocessed, split, and merged, allowing the model to be trained either per-book or on a combined dataset.
# - You need to submit the predicted text for the remaining 6 pages as the output of your model for testing purposes.
#
# ## **Task**
# Train an OCR model to learn from the transcribed pages and generalize to unseen pages. The final output should be predicted transcriptions for the test pages.
#
# ## **Evaluation Metrics**
# See the attached Evaluation Document and Evaluation Pipeline for information on submission layout and guidelines.
#
# ## **Deliverables**
# - A trained OCR model
# - Transcription outputs for the 6 test pages (see Evaluation Document)
# - A brief report covering:
#     - Model architecture and training approach
#     - Preprocessing steps
#     - Evaluation results
# - A usage notebook demonstrating the inference pipeline
# - Completion of pre- and post-hackathon surveys

# %% [markdown]
# # Installs the necessary packages, may ask the users to please restart the notebook

# %%
#%pip install scikit-image PyMuPDF python-docx opencv-python scipy torch torchvision==0.2.1 pillow==8.3.1 natsort requests pandas numpy tensorflow tqdm matplotlib

# %% [markdown]
# You will be prompted to Restart the session. Continue running the cells after restarting

# %% [markdown]
# # Imports the necessary modules

# %%
# Data Pre-processing
import fitz
import cv2
import csv
import os
from docx import Document
import string
import requests
import pandas as pd
import numpy as np
from PIL import Image
import tensorflow as tf
from IPython.display import clear_output as cls
from pathlib import Path

# Data
from glob import glob
from tqdm import tqdm
import tensorflow.data as tfd

# Data Visualization
import matplotlib.pyplot as plt

# Model
from tensorflow import keras
from tensorflow.keras import callbacks
from tensorflow.keras import layers
# Out:
# 2025-07-13 23:06:19.903958: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-13 23:06:23.803186: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Configuration (File Paths for Individual Datasets)

# %%
# Define paths for image folders and outputs
image_folders = {
    "Nobleza Virtuosa": {
        "pdf": Path("data/Padilla - Nobleza virtuosa_testExtract.pdf"),
        "input": Path("content/preprocessing/imgsUnProcessed"),
        "output": Path("content/preprocessing/imgsForAllPages"),
        "processed": Path("content/preprocessing/imgsProcessed"),
        "bounding_boxes": Path("content/preprocessing/BoundBoxApplied"),
        "bounding_boxes_sorted": Path("content/preprocessing/BoundBoxApplied_sorted"),
        "gt_docx": Path("data/Padilla - 1 Nobleza virtuosa_testTranscription.docx"),
        "text_file": Path("content/NoblezaVirtuosa_all_text.txt"),
        "split_text_output": Path("content/preprocessing/textSplitted_NoblezaVirtuosa"),
    },

    "Noble Perfecto": {
        "pdf": Path("data/Padilla - 2 Noble perfecto_Extract.pdf"),
        "input": Path("content/preprocessing/imgsUnProcessed2"),
        "output": Path("content/preprocessing/imgsForAllPages2"),
        "processed": Path("content/preprocessing/imgsProcessed2"),
        "bounding_boxes": Path("content/preprocessing/BoundBoxApplied2"),
        "bounding_boxes_sorted": Path("content/preprocessing/BoundBoxApplied_sorted2"),
        "gt_docx": Path("data/Padilla - 2 Noble perfecto_Transcription.docx"),
        "text_file": Path("content/NoblePerfecto_all_text.txt"),
        "split_text_output": Path("content/preprocessing/textSplitted_NoblePerfecto")
    }
}

# %% [markdown]
# # Downloading the dataset
# #### Includes both books and their transcriptions
# - Padilla - Nobleza Virtuosa
# - Padilla - Noble Perfecto

# %%
PDF_DIR = Path("data")
FOLDER_ID ='195Bh7_Fz2NUWrfkL_t_GUJj4u3GlkjG8?fbclid=IwAR0F2UZl12H90Yk42J0l3rFx-w11fEfEv6AkbURNaXNM81Kf1-2He8VKFao'

gdown_command = f"gdown --folder https://drive.google.com/drive/folders/{FOLDER_ID} -O {PDF_DIR}"
print('Running:', gdown_command)
# !{gdown_command}

print(f"Downloaded PDFs into NLPRenaissanceChallenge/data folder.")
# Out:
# Running: gdown --folder https://drive.google.com/drive/folders/195Bh7_Fz2NUWrfkL_t_GUJj4u3GlkjG8?fbclid=IwAR0F2UZl12H90Yk42J0l3rFx-w11fEfEv6AkbURNaXNM81Kf1-2He8VKFao -O data
# Retrieving folder contents
# Processing file 19A-4DEUtZqn0I_nrM5PdG4RC7jG_IYjT Padilla - Nobleza virtuosa_testExtract.pdf
# Processing file 1B3CjNTp3udRW-qMqKCD9PzkckBQsGvBR Padilla - 2 Noble perfecto_Extract.pdf
# Retrieving folder 1pR0X8FoBNdVtzjyP1_8GbsOO8VeBfqdJ CorrectedData
# Processing file 1voQmAai6dPbtl3ol_fUErrxp1EBMVDEE outputCorrected.zip
# Processing file 1BTjyyqGcAq0i6U84Db6xwXkKc2B4EuCm Padilla - 1 Nobleza virtuosa_testTranscription.docx
# Processing file 1TPQaUA9BCPs0M_vTkgUdmYVHhtxRhdNj Padilla - 2 Noble perfecto_Transcription.docx
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=19A-4DEUtZqn0I_nrM5PdG4RC7jG_IYjT
# To: /home/scs_deal_projects_notapebackup/user/kemeter/DeepLearnHackathon/NLPRenaissanceChallenge/data/Padilla - Nobleza virtuosa_testExtract.pdf
# 100%|██████████████████████████████████████| 2.58M/2.58M [00:00<00:00, 16.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1B3CjNTp3udRW-qMqKCD9PzkckBQsGvBR
# To: /home/scs_deal_projects_notapebackup/user/kemeter/DeepLearnHackathon/NLPRenaissanceChallenge/data/Padilla - 2 Noble perfecto_Extract.pdf
# 100%|██████████████████████████████████████| 3.95M/3.95M [00:00<00:00, 30.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1voQmAai6dPbtl3ol_fUErrxp1EBMVDEE
# To: /home/scs_deal_projects_notapebackup/user/kemeter/DeepLearnHackathon/NLPRenaissanceChallenge/data/CorrectedData/outputCorrected.zip
# 100%|██████████████████████████████████████| 15.9M/15.9M [00:00<00:00, 62.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BTjyyqGcAq0i6U84Db6xwXkKc2B4EuCm
# To: /home/scs_deal_projects_notapebackup/user/kemeter/DeepLearnHackathon/NLPRenaissanceChallenge/data/Padilla - 1 Nobleza virtuosa_testTranscription.docx
# 100%|██████████████████████████████████████| 19.3k/19.3k [00:00<00:00, 2.32MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TPQaUA9BCPs0M_vTkgUdmYVHhtxRhdNj
# To: /home/scs_deal_projects_notapebackup/user/kemeter/DeepLearnHackathon/NLPRenaissanceChallenge/data/Padilla - 2 Noble perfecto_Transcription.docx
# 100%|██████████████████████████████████████| 19.3k/19.3k [00:00<00:00, 3.39MB/s]
# Download completed
# Downloaded PDFs into NLPRenaissanceChallenge/data folder.

# %% [markdown]
# # Applies Pre-Processing Steps to the Datasets

# %% [markdown]
# **PDF → Page Images**
# Converts the original PDF into individual page `.png` images.
#
# **Page Splitting**
# Detects and splits 2-page scans into single-page images based on width.
#
# **Image Preprocessing (For Improved CRAFT Performance)**
#
# Applies denoising, background removal, text enhancement, and contrast boosting, to each page.
#
# **Combine the Datasets**

# %%
for name, paths in image_folders.items():
    print(name, paths)
# Out:
# Nobleza Virtuosa {'pdf': PosixPath('data/Padilla - Nobleza virtuosa_testExtract.pdf'), 'input': PosixPath('content/preprocessing/imgsUnProcessed'), 'output': PosixPath('content/preprocessing/imgsForAllPages'), 'processed': PosixPath('content/preprocessing/imgsProcessed'), 'bounding_boxes': PosixPath('content/preprocessing/BoundBoxApplied'), 'bounding_boxes_sorted': PosixPath('content/preprocessing/BoundBoxApplied_sorted'), 'gt_docx': PosixPath('data/Padilla - 1 Nobleza virtuosa_testTranscription.docx'), 'text_file': PosixPath('content/NoblezaVirtuosa_all_text.txt'), 'split_text_output': PosixPath('content/preprocessing/textSplitted_NoblezaVirtuosa')}
# Noble Perfecto {'pdf': PosixPath('data/Padilla - 2 Noble perfecto_Extract.pdf'), 'input': PosixPath('content/preprocessing/imgsUnProcessed2'), 'output': PosixPath('content/preprocessing/imgsForAllPages2'), 'processed': PosixPath('content/preprocessing/imgsProcessed2'), 'bounding_boxes': PosixPath('content/preprocessing/BoundBoxApplied2'), 'bounding_boxes_sorted': PosixPath('content/preprocessing/BoundBoxApplied_sorted2'), 'gt_docx': PosixPath('data/Padilla - 2 Noble perfecto_Transcription.docx'), 'text_file': PosixPath('content/NoblePerfecto_all_text.txt'), 'split_text_output': PosixPath('content/preprocessing/textSplitted_NoblePerfecto')}

# %%
from utils import run_full_preprocessing_pipeline

for name, paths in image_folders.items():
    run_full_preprocessing_pipeline(
        pdf_path=paths["pdf"],
        output_raw_folder=paths["input"],
        output_split_folder=paths["output"], 
        output_preprocessed_folder=paths["processed"],
        source_suffix= name,
    )
# Out:
# Converting PDF to images...
# Splitting double-page images...
# Preprocessing images...
# Saved preprocessed image: image_1_Nobleza Virtuosa.png
# Saved preprocessed image: image_10_Nobleza Virtuosa.png
# Saved preprocessed image: image_11_Nobleza Virtuosa.png
# Saved preprocessed image: image_12_Nobleza Virtuosa.png
# Saved preprocessed image: image_13_Nobleza Virtuosa.png
# Saved preprocessed image: image_14_Nobleza Virtuosa.png
# Saved preprocessed image: image_15_Nobleza Virtuosa.png
# Saved preprocessed image: image_16_Nobleza Virtuosa.png
# Saved preprocessed image: image_17_Nobleza Virtuosa.png
# Saved preprocessed image: image_18_Nobleza Virtuosa.png
# Saved preprocessed image: image_19_Nobleza Virtuosa.png
# Saved preprocessed image: image_2_Nobleza Virtuosa.png
# Saved preprocessed image: image_20_Nobleza Virtuosa.png
# Saved preprocessed image: image_21_Nobleza Virtuosa.png
# Saved preprocessed image: image_22_Nobleza Virtuosa.png
# Saved preprocessed image: image_23_Nobleza Virtuosa.png
# Saved preprocessed image: image_24_Nobleza Virtuosa.png
# Saved preprocessed image: image_25_Nobleza Virtuosa.png
# Saved preprocessed image: image_26_Nobleza Virtuosa.png
# Saved preprocessed image: image_27_Nobleza Virtuosa.png
# Saved preprocessed image: image_28_Nobleza Virtuosa.png
# Saved preprocessed image: image_29_Nobleza Virtuosa.png
# Saved preprocessed image: image_3_Nobleza Virtuosa.png
# Saved preprocessed image: image_30_Nobleza Virtuosa.png
# Saved preprocessed image: image_31_Nobleza Virtuosa.png
# Saved preprocessed image: image_4_Nobleza Virtuosa.png
# Saved preprocessed image: image_5_Nobleza Virtuosa.png
# Saved preprocessed image: image_6_Nobleza Virtuosa.png
# Saved preprocessed image: image_7_Nobleza Virtuosa.png
# Saved preprocessed image: image_8_Nobleza Virtuosa.png
# Saved preprocessed image: image_9_Nobleza Virtuosa.png
# Full preprocessing pipeline complete.
# Converting PDF to images...
# Splitting double-page images...
# Preprocessing images...
# Saved preprocessed image: image_1_Noble Perfecto.png
# Saved preprocessed image: image_10_Noble Perfecto.png
# Saved preprocessed image: image_11_Noble Perfecto.png
# Saved preprocessed image: image_12_Noble Perfecto.png
# Saved preprocessed image: image_13_Noble Perfecto.png
# Saved preprocessed image: image_14_Noble Perfecto.png
# Saved preprocessed image: image_15_Noble Perfecto.png
# Saved preprocessed image: image_16_Noble Perfecto.png
# Saved preprocessed image: image_17_Noble Perfecto.png
# Saved preprocessed image: image_18_Noble Perfecto.png
# Saved preprocessed image: image_19_Noble Perfecto.png
# Saved preprocessed image: image_2_Noble Perfecto.png
# Saved preprocessed image: image_20_Noble Perfecto.png
# Saved preprocessed image: image_21_Noble Perfecto.png
# Saved preprocessed image: image_22_Noble Perfecto.png
# Saved preprocessed image: image_23_Noble Perfecto.png
# Saved preprocessed image: image_24_Noble Perfecto.png
# Saved preprocessed image: image_25_Noble Perfecto.png
# Saved preprocessed image: image_26_Noble Perfecto.png
# Saved preprocessed image: image_27_Noble Perfecto.png
# Saved preprocessed image: image_28_Noble Perfecto.png
# Saved preprocessed image: image_29_Noble Perfecto.png
# Saved preprocessed image: image_3_Noble Perfecto.png
# Saved preprocessed image: image_30_Noble Perfecto.png
# Saved preprocessed image: image_31_Noble Perfecto.png
# Saved preprocessed image: image_4_Noble Perfecto.png
# Saved preprocessed image: image_5_Noble Perfecto.png
# Saved preprocessed image: image_6_Noble Perfecto.png
# Saved preprocessed image: image_7_Noble Perfecto.png
# Saved preprocessed image: image_8_Noble Perfecto.png
# Saved preprocessed image: image_9_Noble Perfecto.png
# Full preprocessing pipeline complete.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ML4SCI/DeepLearnHackathon/main/NLPRenaissanceChallenge/images/imageOriginal.png">

# %%
#!git clone https://github.com/ML4SCI/DeepLearnHackathon.git

# %% [markdown]
# # Text Detection
# ### Extracting words from a scanned text page image may be achieved using any model of your choice!
# We are using the [CRAFT Model](https://github.com/clovaai/CRAFT-pytorch) for the same. (This will take 3-4 mins to process the entire model)

# %%
#It generally takes about ~3-4 mins
for name in image_folders:
    result = str(image_folders[name]['bounding_boxes'])
    test = str(image_folders[name]['processed'])

    #!python CRAFT_Model/CRAFT/BoundBoxFunc/test.py --result_folder={result}  --test_folder={test}  --trained_model="CRAFT_Model/CRAFT/BoundBoxFunc/weights/craft_mlt_25k.pth"
    # !python CRAFT-pytorch/test.py --trained_model=CRAFT-pytorch/weights/craft_mlt_25k.pth --test_folder={test} --result_folder={result}
# Out:
# Loading weights from checkpoint (CRAFT-pytorch/weights/craft_mlt_25k.pth)
# CRAFT-pytorch/test.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(copyStateDict(torch.load(args.trained_model)))
# elapsed time : 10.828368902206421sssing/imgsProcessed/image_9_Nobleza Virtuosa.pngg
# Loading weights from checkpoint (CRAFT-pytorch/weights/craft_mlt_25k.pth)
# CRAFT-pytorch/test.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(copyStateDict(torch.load(args.trained_model)))
# elapsed time : 9.851253032684326sessing/imgsProcessed2/image_9_Noble Perfecto.pngg

# %% [markdown]
# ### The output of this model provides coordinates of the polygon enclosing the word.
# Using these coordinates a bounding box can be drawn, and from there word images may be cropped.

# %%
from utils import sort_bounding_boxes

sort_bounding_boxes(input_dir=image_folders["Nobleza Virtuosa"]["bounding_boxes"], output_dir=image_folders["Nobleza Virtuosa"]["bounding_boxes_sorted"],)
sort_bounding_boxes(input_dir=image_folders["Noble Perfecto"]["bounding_boxes"], output_dir=image_folders["Noble Perfecto"]["bounding_boxes_sorted"],)
# Out:
# Processing bounding boxes in: content/preprocessing/BoundBoxApplied
# Sorted boxes written: res_image_1_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_10_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_11_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_12_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_13_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_14_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_15_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_16_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_17_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_18_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_19_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_2_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_20_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_21_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_22_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_23_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_24_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_25_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_26_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_27_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_28_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_29_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_3_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_30_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_31_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_4_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_5_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_6_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_7_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_8_Nobleza Virtuosa_sorted.txt
# Sorted boxes written: res_image_9_Nobleza Virtuosa_sorted.txt
# All bounding boxes sorted. Output in: content/preprocessing/BoundBoxApplied_sorted
# Processing bounding boxes in: content/preprocessing/BoundBoxApplied2
# Sorted boxes written: res_image_1_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_10_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_11_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_12_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_13_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_14_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_15_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_16_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_17_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_18_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_19_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_2_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_20_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_21_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_22_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_23_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_24_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_25_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_26_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_27_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_28_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_29_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_3_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_30_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_31_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_4_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_5_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_6_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_7_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_8_Noble Perfecto_sorted.txt
# Sorted boxes written: res_image_9_Noble Perfecto_sorted.txt
# All bounding boxes sorted. Output in: content/preprocessing/BoundBoxApplied_sorted2

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ML4SCI/DeepLearnHackathon/main/NLPRenaissanceChallenge/images/imageCRAFT.jpg">

# %% [markdown]
# ### Extracts all the words from .docx file for each dataset, which contains the Transcriptions (True Labels).

# %%
import importlib
from utils import extract_ground_truth_for_dataset

extract_ground_truth_for_dataset(
    docx_file="data/Padilla - 1 Nobleza virtuosa_testTranscription.docx",
    output_path="content/NoblezaVirtuosa_all_text.txt"
)
extract_ground_truth_for_dataset(
    docx_file="data/Padilla - 2 Noble perfecto_Transcription.docx",
    output_path="content/NoblePerfecto_all_text.txt"
)
# Out:
# Ground truth text saved to content/NoblezaVirtuosa_all_text.txt
# Ground truth text saved to content/NoblePerfecto_all_text.txt

# %% [markdown]
# ### Since the text book is now processed into individual pages, we need to split the entire transcription based on text pages.

# %%
from utils import process_textfiles
import os

for name, paths in image_folders.items():
    textfile = paths["text_file"]
    sorted_BoundBox_folder = paths["bounding_boxes_sorted"]
    output_folder = paths["split_text_output"]
    os.makedirs(output_folder, exist_ok=True)
    print(f"Splitting text for {name}...")
    process_textfiles(textfile, sorted_BoundBox_folder, output_folder)
    print(f"Text splitting complete for {name}! Output: {output_folder}")
# Out:
# Splitting text for Nobleza Virtuosa...
# Found 25 text pages and 31 bbox files.
# Not enough text pages for res_image_26_Nobleza Virtuosa_sorted.txt
# Text splitting complete. Output written to: content/preprocessing/textSplitted_NoblezaVirtuosa
# Text splitting complete for Nobleza Virtuosa! Output: content/preprocessing/textSplitted_NoblezaVirtuosa
# Splitting text for Noble Perfecto...
# Found 25 text pages and 31 bbox files.
# Not enough text pages for res_image_26_Noble Perfecto_sorted.txt
# Text splitting complete. Output written to: content/preprocessing/textSplitted_NoblePerfecto
# Text splitting complete for Noble Perfecto! Output: content/preprocessing/textSplitted_NoblePerfecto

# %% [markdown]
# ### Extracts and saves bounding boxes from images using text data for filenames
# Skipping the last 6 images which will be used later for testing.

# %%
from utils import apply_extraction_to_folder_for_train

for name, paths in image_folders.items():
    apply_extraction_to_folder_for_train(
        image_folder=paths["processed"],
        bounding_box_folder=paths["bounding_boxes_sorted"],
        text_folder=paths["split_text_output"],
        output_folder="content/train_data/",
    )
# Out:
# All pages processed. Extracted data saved to: content/train_data
#
# All pages processed. Extracted data saved to: content/train_data

# %% [markdown]
# ###  Extracts and saves bounding boxes from images using a numeric counter for filenames
# Skipping the first 25 images as they will not be used for testing.

# %%
from utils import apply_extraction_to_folder_for_test

for name, paths in image_folders.items():
    apply_extraction_to_folder_for_test(
        image_folder=paths["processed"],
        bounding_box_folder=paths["bounding_boxes_sorted"],
        output_folder="content/test_data/",
    )
# Out:
# Test extraction complete. Output in: content/test_data
# Test extraction complete. Output in: content/test_data

# %% [markdown]
# ### Pad and resize images of words within bounding boxes for better visualisation

# %%
from utils import pad_and_resize_images

pad_and_resize_images("content/train_data")
pad_and_resize_images("content/train_data")
# Out:
# Processed: content/train_data/image_1_Nobleza Virtuosa/DEDICATORIA.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/EN.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/dexo.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/mayores.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/destos.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/Reynos.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/España.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/por.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/tos.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/nombre..png
# Processed: content/train_data/image_1_Nobleza Virtuosa/SIENDO.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/(hijos.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/mios).png
# Processed: content/train_data/image_1_Nobleza Virtuosa/tan.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/es.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/gacion.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/han.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/dres,.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/ellos.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/desseando.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/te.png
# Processed: content/train_data/image_1_Nobleza Virtuosa/vuestra,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/tro.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/tos.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/juyzios.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/festasse,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/ha.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/rendida.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/fermedad.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/tal,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/pio.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/vuestra.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/asi.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/pues.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/como.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/os.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/dolores,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/con.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/cidentes,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/ahora.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/Dios,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/para.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/exorto.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/(que.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/he.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/recogido.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/lo.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/mable.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/herencia.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/puedo.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/prendas.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/tengo,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/por.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/este,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/lugar.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/pido,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/paga.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/premio.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/bendicion,.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/desde.png
# Processed: content/train_data/image_2_Nobleza Virtuosa/aquí.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/celentes.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/un.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/tu.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/largamente.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/escribe,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/ma:.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/providencia.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/particular.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/vosotros,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/os.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/concedera.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/Santo,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/sus.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/bre.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/sobrenatural,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/buena.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/conciencia,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/esperanza.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/divina.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/bertad,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/paz.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/interior,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/oydo.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/grato.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/vuestras.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/oraciones,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/favor.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/los.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/virtuosos.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/ultimamente,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/fin,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/diera.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/sernos.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/incentivo.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/para.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/camino.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/nos.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/tuviera.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/Dios.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/bligados.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/por.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/inestimables.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/nerales.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/cion,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/redempcion,.png
# Processed: content/train_data/image_3_Nobleza Virtuosa/justificacion,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/predeterminacion,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/da.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/uno.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/los.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/os.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/hago.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/dio,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/se.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/qualquiera.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/verdadera.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/nobleza,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/pues.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/es.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/deuda,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/sed.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/mirad.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/no.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/forzosa.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/muestra.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/animo,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/como.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/dixo.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/no,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/puede.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/su.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/za.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/lla.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/queda.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/cadaver.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/alma,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/vida.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/nobleza.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/ella.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/tiene.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/mayor.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/las.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/armas,.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/aunque.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/este.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/misma.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/haze.png
# Processed: content/train_data/image_4_Nobleza Virtuosa/luz.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/ella.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/so:.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/es.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/tan.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/mal.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/nada,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/sujeto.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/propio,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/más.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/excelente,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/pues.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/corazon,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/Principes,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/quita.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/pinas.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/vida,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/tienen.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/las.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/calamidades.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/niebla.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/tes.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/preguntado..png
# Processed: content/train_data/image_5_Nobleza Virtuosa/Por.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/Iorgias,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/nía.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/por.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/dichoso.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/al.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/respondio:.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/so,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/sin.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/saber.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/quanta.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/virtud.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/conforma.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/con.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/esto.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/después.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/ye,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/aventurada,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/añade,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/sola.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/propio.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/bien.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/del.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/hombre,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/das.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/sumen,.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/raleza.png
# Processed: content/train_data/image_5_Nobleza Virtuosa/eterna,.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/sa.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/toque..png
# Processed: content/train_data/image_6_Nobleza Virtuosa/Para.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/es.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/blo.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/adelante.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/teles,.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/lo.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/recto,.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/bre.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/San.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/Agustin,.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/una.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/qualidad.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/vive.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/rectamente,.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/os.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/gándole.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/vuestra.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/parte;.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/yo.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/vida.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/para.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/ella.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/mucha.png
# Processed: content/train_data/image_6_Nobleza Virtuosa/gloria..png
# Processed: content/train_data/image_7_Nobleza Virtuosa/Consejos.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/dexó.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/Señora.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/Primogénito..png
# Processed: content/train_data/image_7_Nobleza Virtuosa/No.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/ños.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/más.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/mundo,.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/turales,.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/gunos.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/por.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/privilegio.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/dados,.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/samente.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/con.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/desprecio.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/fluos.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/entregandose.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/tal.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/genero.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/vicios,.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/campal.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/mayor..png
# Processed: content/train_data/image_7_Nobleza Virtuosa/grandes.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/Señores,.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/verdadera.png
# Processed: content/train_data/image_7_Nobleza Virtuosa/mayor,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/pia.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/(que.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/procuran).png
# Processed: content/train_data/image_8_Nobleza Virtuosa/pero.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/son.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/mas.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/los.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/dexandose.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/llevar.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/naciones.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/depravadas,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/(peste.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/hallan,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/tomando.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/por.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/armas.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/contra.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/Dios,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/ron,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/piensan.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/se.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/engrandecen,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/pues.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/das.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/tin:.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/no.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/conocieron.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/ron.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/abatio,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/verdadera.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/vemos.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/sectarios,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/cabezas.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/vicios,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/professando.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/tia.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/graciosos,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/hurtando.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/truhanes,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/otros.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/sabios.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/inchado,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/unos.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/enfadados.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/todos,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/descorteses,.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/Poetas.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/con.png
# Processed: content/train_data/image_8_Nobleza Virtuosa/agenos.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/versos:.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/los.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/son,.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/enamorados<.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/llega.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/como.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/truxeron.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/casi.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/toda.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/su.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/lo.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/tan.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/indignamente.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/posseen..png
# Processed: content/train_data/image_9_Nobleza Virtuosa/Tampoco.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/faltan.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/otros,.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/gracia.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/ni.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/tratar.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/verdad<.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/chos.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/años.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/digno.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/educación.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/sus.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/Nobles,.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/presentarle.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/yo.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/verdades,.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/fealdad.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/horror.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/della.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/les.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/cobreys.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/cimiento.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/tamente,.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/nde.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/(no.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/llos).png
# Processed: content/train_data/image_9_Nobleza Virtuosa/ha.png
# Processed: content/train_data/image_9_Nobleza Virtuosa/cio.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/nima.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/connatural.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/los.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/corazon.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/grande,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/preciar.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/abatirse.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/teles,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/Ciceron,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/consiste.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/sas,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/sufrir.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/ella.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/acometer.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/arduas.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/grandes.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/presas.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/taleza.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/Christiana,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/es.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/mucho.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/por.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/Dios,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/mo,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/triunfo.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/esta.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/vinculada.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/verdadera.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/grandeza..png
# Processed: content/train_data/image_10_Nobleza Virtuosa/pues,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/dio.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/Dios.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/para.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/repartirla,.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/aveys.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/nacido.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/tanto.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/como.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/vos.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/mismo:.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/Ciceron.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/son.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/talentos.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/cuenta.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/muy.png
# Processed: content/train_data/image_10_Nobleza Virtuosa/estrecha,.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/seguidor.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/los.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/vicios.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/quantos.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/corrieren.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/por.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/ta,.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/según.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/manos.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/ra.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/entrar.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/passar.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/primero.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/profession.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/obligaros.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/esto,.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/agravio.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/hallar.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/Prelados,.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/ser.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/limosneros:.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/Religiosos,.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/zelo.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/devo-.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/cion.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/:.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/cio.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/valor.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/alentado.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/corazon.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/dres.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/Familias,.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/para.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/con.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/Artifices,.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/huyr.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/ociosidad,.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/rin-.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/diendose.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/al.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/incansable.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/es.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/obligacion.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/poner.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/qual.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/pagan.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/las.png
# Processed: content/train_data/image_11_Nobleza Virtuosa/rentas,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/desuelo.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/no.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/tamente..png
# Processed: content/train_data/image_12_Nobleza Virtuosa/Si.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/Dios,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/exercitar.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/con.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/su.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/divina.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/las.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/tres.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/Virtudes.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/Cardinales,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/Morales.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/cia.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/subditos,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/Fortaleza,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/Templanza,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/Continencia.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/diencia.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/vuestro.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/(que.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/lo.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/todos,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/dos.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/cia,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/siones.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/pidieren).png
# Processed: content/train_data/image_12_Nobleza Virtuosa/familiares,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/amigos,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/signacion.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/prosperidades,.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/animo.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/agradecido.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/desprecio.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/to.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/selas.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/el..png
# Processed: content/train_data/image_12_Nobleza Virtuosa/aquí.png
# Processed: content/train_data/image_12_Nobleza Virtuosa/individuaros,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/amor,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/obligacion.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/descuento.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/propio.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/suyo,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/los.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/crian.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/afeminados,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/las.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/costumbres..png
# Processed: content/train_data/image_13_Nobleza Virtuosa/Bien.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/veo,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/do.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/tan.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/varias.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/nas,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/es.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/preceptos.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/trato.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/van.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/sugetas.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/al.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/dominio.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/encia,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/cación,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/según.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/estados,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/lugares,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/condiciones,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/ta.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/virtud,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/q.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/das,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/Cicero.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/vida,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/luz.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/dera.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/tuoso,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/cuya.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/San.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/Basilio,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/ay.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/una.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/fagacidad,.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/siempre.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/da.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/veniencia.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/primera.png
# Processed: content/train_data/image_13_Nobleza Virtuosa/os.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/usad.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/con.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/las.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/maquinas.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/ser.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/engañado.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/dellos..png
# Processed: content/train_data/image_14_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/llegareys.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/tos.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/consejos,.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/buenos.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Cavalleros,.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/grandes.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/res,.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/perador.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Carlo.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/mundo.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/sus.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/grandezas.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Quinto,.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Luys,.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/constancia.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/del.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Rey.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Ingles.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/justicia.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Bullon,.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/prudencia.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/do.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/beralidad.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/estudiosidad,.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Don.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Alonso.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/tan.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/conocido.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/teniendo.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/lor.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/trado.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/realce.png
# Processed: content/train_data/image_14_Nobleza Virtuosa/Fe,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Numa,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Anibal,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Socrates,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/pion,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/xandro,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Marco.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Aurelio,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/atribuyen.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/las.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/faltandoles.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/la.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/verdadera.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/dieron.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/todos.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/no.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/quadraredes.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/(que.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/es.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/imposible).png
# Processed: content/train_data/image_15_Nobleza Virtuosa/do.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/los.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/aunque.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/parte,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/principalmente.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/con.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/hazer.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/lo.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Para.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/cante.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Religion.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/PUES.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/mejor,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/cierto.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/principio.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/cosas.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/guia,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/to.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/(y.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/conocieron.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/esto.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/aun.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Gentiles,.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Tito.png
# Processed: content/train_data/image_15_Nobleza Virtuosa/Livio.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/nos.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/dexo.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/escrito:.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/todo.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/le.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/sucede.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/bien.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/cipio,.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/y.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/assi.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/lo.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/sintieron.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/ceron,.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/Socrates,.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/primero,.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/que.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/el.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/titulo.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/principal.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/de.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/os.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/ser.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/asentado.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/faltar.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/a.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/servaros.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/en.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/bistes.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/siempre.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/aveys.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/digno..png
# Processed: content/train_data/image_16_Nobleza Virtuosa/En.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/las.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/cosas.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/tocantes.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/dad.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/cion,.png
# Processed: content/train_data/image_16_Nobleza Virtuosa/asistid.png
# ...
# Processed: content/train_data/image_20_Noble Perfecto/grande.png
# Processed: content/train_data/image_20_Noble Perfecto/dos.png
# Processed: content/train_data/image_20_Noble Perfecto/virtudes.png
# Processed: content/train_data/image_20_Noble Perfecto/de.png
# Processed: content/train_data/image_20_Noble Perfecto/stidad,.png
# Processed: content/train_data/image_20_Noble Perfecto/Dios,.png
# Processed: content/train_data/image_20_Noble Perfecto/y.png
# Processed: content/train_data/image_20_Noble Perfecto/les.png
# Processed: content/train_data/image_20_Noble Perfecto/muy.png
# Processed: content/train_data/image_20_Noble Perfecto/cia.png
# Processed: content/train_data/image_20_Noble Perfecto/memorable.png
# Processed: content/train_data/image_20_Noble Perfecto/dixo.png
# Processed: content/train_data/image_20_Noble Perfecto/Seneca:.png
# Processed: content/train_data/image_20_Noble Perfecto/Si.png
# Processed: content/train_data/image_20_Noble Perfecto/supiesse,.png
# Processed: content/train_data/image_20_Noble Perfecto/Dioses.png
# Processed: content/train_data/image_20_Noble Perfecto/avian.png
# Processed: content/train_data/image_20_Noble Perfecto/dexaria.png
# Processed: content/train_data/image_20_Noble Perfecto/incontinencia,.png
# Processed: content/train_data/image_20_Noble Perfecto/solo.png
# Processed: content/train_data/image_20_Noble Perfecto/del..png
# Processed: content/train_data/image_20_Noble Perfecto/Con.png
# Processed: content/train_data/image_20_Noble Perfecto/almas,.png
# Processed: content/train_data/image_20_Noble Perfecto/ponen.png
# Processed: content/train_data/image_20_Noble Perfecto/salud,.png
# Processed: content/train_data/image_20_Noble Perfecto/destruyen.png
# Processed: content/train_data/image_20_Noble Perfecto/la.png
# Processed: content/train_data/image_21_Noble Perfecto/ziendas,.png
# Processed: content/train_data/image_21_Noble Perfecto/hazense.png
# Processed: content/train_data/image_21_Noble Perfecto/brutos,.png
# Processed: content/train_data/image_21_Noble Perfecto/gos.png
# Processed: content/train_data/image_21_Noble Perfecto/entendimientos,.png
# Processed: content/train_data/image_21_Noble Perfecto/nuo.png
# Processed: content/train_data/image_21_Noble Perfecto/escandalo.png
# Processed: content/train_data/image_21_Noble Perfecto/de.png
# Processed: content/train_data/image_21_Noble Perfecto/assi.png
# Processed: content/train_data/image_21_Noble Perfecto/tar.png
# Processed: content/train_data/image_21_Noble Perfecto/los.png
# Processed: content/train_data/image_21_Noble Perfecto/mozos.png
# Processed: content/train_data/image_21_Noble Perfecto/preservandolos.png
# Processed: content/train_data/image_21_Noble Perfecto/juntamente.png
# Processed: content/train_data/image_21_Noble Perfecto/tros.png
# Processed: content/train_data/image_21_Noble Perfecto/vicios,.png
# Processed: content/train_data/image_21_Noble Perfecto/que.png
# Processed: content/train_data/image_21_Noble Perfecto/suelen.png
# Processed: content/train_data/image_21_Noble Perfecto/echar.png
# Processed: content/train_data/image_21_Noble Perfecto/muy.png
# Processed: content/train_data/image_21_Noble Perfecto/hondas.png
# Processed: content/train_data/image_21_Noble Perfecto/uno.png
# Processed: content/train_data/image_21_Noble Perfecto/dellos.png
# Processed: content/train_data/image_21_Noble Perfecto/es.png
# Processed: content/train_data/image_21_Noble Perfecto/el.png
# Processed: content/train_data/image_21_Noble Perfecto/Seneca.png
# Processed: content/train_data/image_21_Noble Perfecto/rro.png
# Processed: content/train_data/image_21_Noble Perfecto/rabioso,.png
# Processed: content/train_data/image_21_Noble Perfecto/de,.png
# Processed: content/train_data/image_21_Noble Perfecto/dura.png
# Processed: content/train_data/image_21_Noble Perfecto/da.png
# Processed: content/train_data/image_21_Noble Perfecto/la.png
# Processed: content/train_data/image_21_Noble Perfecto/vida;.png
# Processed: content/train_data/image_21_Noble Perfecto/y.png
# Processed: content/train_data/image_21_Noble Perfecto/nos,.png
# Processed: content/train_data/image_21_Noble Perfecto/perder,.png
# Processed: content/train_data/image_21_Noble Perfecto/cobran.png
# Processed: content/train_data/image_21_Noble Perfecto/deven.png
# Processed: content/train_data/image_21_Noble Perfecto/mucho.png
# Processed: content/train_data/image_21_Noble Perfecto/temerse:.png
# Processed: content/train_data/image_21_Noble Perfecto/otro.png
# Processed: content/train_data/image_21_Noble Perfecto/mentir,.png
# Processed: content/train_data/image_21_Noble Perfecto/falta.png
# Processed: content/train_data/image_21_Noble Perfecto/tan.png
# Processed: content/train_data/image_21_Noble Perfecto/mas.png
# Processed: content/train_data/image_21_Noble Perfecto/en.png
# Processed: content/train_data/image_21_Noble Perfecto/por.png
# Processed: content/train_data/image_21_Noble Perfecto/ella.png
# Processed: content/train_data/image_21_Noble Perfecto/determino.png
# Processed: content/train_data/image_21_Noble Perfecto/Marco.png
# Processed: content/train_data/image_21_Noble Perfecto/Aurelio.png
# Processed: content/train_data/image_21_Noble Perfecto/privar.png
# Processed: content/train_data/image_21_Noble Perfecto/del.png
# Processed: content/train_data/image_21_Noble Perfecto/a.png
# Processed: content/train_data/image_21_Noble Perfecto/Commodo.png
# Processed: content/train_data/image_21_Noble Perfecto/su.png
# Processed: content/train_data/image_21_Noble Perfecto/hijo.png
# Processed: content/train_data/image_21_Noble Perfecto/(aunque.png
# Processed: content/train_data/image_21_Noble Perfecto/consiguio,.png
# Processed: content/train_data/image_21_Noble Perfecto/edad.png
# Processed: content/train_data/image_21_Noble Perfecto/virtuoso,.png
# Processed: content/train_data/image_21_Noble Perfecto/quien.png
# Processed: content/train_data/image_21_Noble Perfecto/tenia.png
# Processed: content/train_data/image_21_Noble Perfecto/puestas.png
# Processed: content/train_data/image_22_Noble Perfecto/Este.png
# Processed: content/train_data/image_22_Noble Perfecto/Principe,.png
# Processed: content/train_data/image_22_Noble Perfecto/virtud.png
# Processed: content/train_data/image_22_Noble Perfecto/y.png
# Processed: content/train_data/image_22_Noble Perfecto/beza.png
# Processed: content/train_data/image_22_Noble Perfecto/del.png
# Processed: content/train_data/image_22_Noble Perfecto/mundo,.png
# Processed: content/train_data/image_22_Noble Perfecto/aviendo.png
# Processed: content/train_data/image_22_Noble Perfecto/desuelo.png
# Processed: content/train_data/image_22_Noble Perfecto/Maestros.png
# Processed: content/train_data/image_22_Noble Perfecto/para.png
# Processed: content/train_data/image_22_Noble Perfecto/el.png
# Processed: content/train_data/image_22_Noble Perfecto/modo,.png
# Processed: content/train_data/image_22_Noble Perfecto/les.png
# Processed: content/train_data/image_22_Noble Perfecto/dixo.png
# Processed: content/train_data/image_22_Noble Perfecto/al.png
# Processed: content/train_data/image_22_Noble Perfecto/garsele,.png
# Processed: content/train_data/image_22_Noble Perfecto/las.png
# Processed: content/train_data/image_22_Noble Perfecto/palabras.png
# Processed: content/train_data/image_22_Noble Perfecto/por.png
# Processed: content/train_data/image_22_Noble Perfecto/los.png
# Processed: content/train_data/image_22_Noble Perfecto/referir.png
# Processed: content/train_data/image_22_Noble Perfecto/aquí:.png
# Processed: content/train_data/image_22_Noble Perfecto/ze,.png
# Processed: content/train_data/image_22_Noble Perfecto/lo.png
# Processed: content/train_data/image_22_Noble Perfecto/enseñar.png
# Processed: content/train_data/image_22_Noble Perfecto/en.png
# Processed: content/train_data/image_22_Noble Perfecto/la.png
# Processed: content/train_data/image_22_Noble Perfecto/tierra,.png
# Processed: content/train_data/image_22_Noble Perfecto/Deidades.png
# Processed: content/train_data/image_22_Noble Perfecto/que.png
# Processed: content/train_data/image_22_Noble Perfecto/ha.png
# Processed: content/train_data/image_22_Noble Perfecto/de.png
# Processed: content/train_data/image_22_Noble Perfecto/doctrinar,.png
# Processed: content/train_data/image_22_Noble Perfecto/chos.png
# Processed: content/train_data/image_22_Noble Perfecto/un.png
# Processed: content/train_data/image_22_Noble Perfecto/Principe.png
# Processed: content/train_data/image_22_Noble Perfecto/governalle.png
# Processed: content/train_data/image_22_Noble Perfecto/tandarte.png
# Processed: content/train_data/image_22_Noble Perfecto/exercito,.png
# Processed: content/train_data/image_22_Noble Perfecto/guion.png
# Processed: content/train_data/image_22_Noble Perfecto/yes,.png
# Processed: content/train_data/image_22_Noble Perfecto/minos,.png
# Processed: content/train_data/image_22_Noble Perfecto/padre.png
# Processed: content/train_data/image_22_Noble Perfecto/ranza.png
# Processed: content/train_data/image_22_Noble Perfecto/pobres,.png
# Processed: content/train_data/image_22_Noble Perfecto/publica..png
# Processed: content/train_data/image_22_Noble Perfecto/Encargo.png
# Processed: content/train_data/image_22_Noble Perfecto/os.png
# Processed: content/train_data/image_22_Noble Perfecto/no.png
# Processed: content/train_data/image_22_Noble Perfecto/tiene.png
# Processed: content/train_data/image_23_Noble Perfecto/que.png
# Processed: content/train_data/image_23_Noble Perfecto/de.png
# Processed: content/train_data/image_23_Noble Perfecto/dormir.png
# Processed: content/train_data/image_23_Noble Perfecto/fia,.png
# Processed: content/train_data/image_23_Noble Perfecto/mayor.png
# Processed: content/train_data/image_23_Noble Perfecto/la.png
# Processed: content/train_data/image_23_Noble Perfecto/preservarle.png
# Processed: content/train_data/image_23_Noble Perfecto/los.png
# Processed: content/train_data/image_23_Noble Perfecto/vicios;.png
# Processed: content/train_data/image_23_Noble Perfecto/rad.png
# Processed: content/train_data/image_23_Noble Perfecto/quan.png
# Processed: content/train_data/image_23_Noble Perfecto/pague.png
# Processed: content/train_data/image_23_Noble Perfecto/enseñeis.png
# Processed: content/train_data/image_23_Noble Perfecto/sutileza.png
# Processed: content/train_data/image_23_Noble Perfecto/palabras.png
# Processed: content/train_data/image_23_Noble Perfecto/to.png
# Processed: content/train_data/image_23_Noble Perfecto/Dioses,.png
# Processed: content/train_data/image_23_Noble Perfecto/antiguos.png
# Processed: content/train_data/image_23_Noble Perfecto/cianos.png
# Processed: content/train_data/image_23_Noble Perfecto/nos.png
# Processed: content/train_data/image_23_Noble Perfecto/lo.png
# Processed: content/train_data/image_23_Noble Perfecto/te.png
# Processed: content/train_data/image_23_Noble Perfecto/dello.png
# Processed: content/train_data/image_23_Noble Perfecto/ni.png
# Processed: content/train_data/image_23_Noble Perfecto/han.png
# Processed: content/train_data/image_23_Noble Perfecto/quien.png
# Processed: content/train_data/image_23_Noble Perfecto/mas.png
# Processed: content/train_data/image_23_Noble Perfecto/obligado.png
# Processed: content/train_data/image_23_Noble Perfecto/el.png
# Processed: content/train_data/image_23_Noble Perfecto/destetar.png
# Processed: content/train_data/image_24_Noble Perfecto/galo,.png
# Processed: content/train_data/image_24_Noble Perfecto/tuoso..png
# Processed: content/train_data/image_24_Noble Perfecto/Mueve.png
# Processed: content/train_data/image_24_Noble Perfecto/hombre.png
# Processed: content/train_data/image_24_Noble Perfecto/de.png
# Processed: content/train_data/image_24_Noble Perfecto/el.png
# Processed: content/train_data/image_24_Noble Perfecto/que.png
# Processed: content/train_data/image_24_Noble Perfecto/es.png
# Processed: content/train_data/image_24_Noble Perfecto/ve.png
# Processed: content/train_data/image_24_Noble Perfecto/reprobar,.png
# Processed: content/train_data/image_24_Noble Perfecto/do.png
# Processed: content/train_data/image_24_Noble Perfecto/moria.png
# Processed: content/train_data/image_24_Noble Perfecto/lo.png
# Processed: content/train_data/image_24_Noble Perfecto/mas.png
# Processed: content/train_data/image_24_Noble Perfecto/cargo.png
# Processed: content/train_data/image_24_Noble Perfecto/grande.png
# Processed: content/train_data/image_24_Noble Perfecto/por.png
# Processed: content/train_data/image_24_Noble Perfecto/infinitos.png
# Processed: content/train_data/image_24_Noble Perfecto/exemplos.png
# Processed: content/train_data/image_24_Noble Perfecto/tura.png
# Processed: content/train_data/image_24_Noble Perfecto/Sagrada.png
# Processed: content/train_data/image_24_Noble Perfecto/den.png
# Processed: content/train_data/image_24_Noble Perfecto/educacion.png
# Processed: content/train_data/image_24_Noble Perfecto/esto.png
# Processed: content/train_data/image_24_Noble Perfecto/importara.png
# Processed: content/train_data/image_24_Noble Perfecto/mucho.png
# Processed: content/train_data/image_24_Noble Perfecto/aprecio.png
# Processed: content/train_data/image_24_Noble Perfecto/la.png
# Processed: content/train_data/image_24_Noble Perfecto/dignidad.png
# Processed: content/train_data/image_24_Noble Perfecto/calificada.png
# Processed: content/train_data/image_24_Noble Perfecto/con.png
# Processed: content/train_data/image_24_Noble Perfecto/a.png
# Processed: content/train_data/image_24_Noble Perfecto/los.png
# Processed: content/train_data/image_24_Noble Perfecto/hombres.png
# Processed: content/train_data/image_24_Noble Perfecto/yos,.png
# Processed: content/train_data/image_24_Noble Perfecto/sto,.png
# Processed: content/train_data/image_24_Noble Perfecto/como.png
# Processed: content/train_data/image_24_Noble Perfecto/mente.png
# Processed: content/train_data/image_24_Noble Perfecto/drino..png
# Processed: content/train_data/image_25_Noble Perfecto/EXHORTACION.png
# Processed: content/train_data/image_25_Noble Perfecto/a.png
# Processed: content/train_data/image_25_Noble Perfecto/De.png
# Processed: content/train_data/image_25_Noble Perfecto/seria.png
# Processed: content/train_data/image_25_Noble Perfecto/hijos.png
# Processed: content/train_data/image_25_Noble Perfecto/desuelo.png
# Processed: content/train_data/image_25_Noble Perfecto/tros.png
# Processed: content/train_data/image_25_Noble Perfecto/padres,.png
# Processed: content/train_data/image_25_Noble Perfecto/buscar.png
# Processed: content/train_data/image_25_Noble Perfecto/Maestros.png
# Processed: content/train_data/image_25_Noble Perfecto/quien.png
# Processed: content/train_data/image_25_Noble Perfecto/se.png
# Processed: content/train_data/image_25_Noble Perfecto/pueda.png
# Processed: content/train_data/image_25_Noble Perfecto/fiar.png
# Processed: content/train_data/image_25_Noble Perfecto/como.png
# Processed: content/train_data/image_25_Noble Perfecto/vuestra.png
# Processed: content/train_data/image_25_Noble Perfecto/educacion,.png
# Processed: content/train_data/image_25_Noble Perfecto/neys.png
# Processed: content/train_data/image_25_Noble Perfecto/en.png
# Processed: content/train_data/image_25_Noble Perfecto/xando.png
# Processed: content/train_data/image_25_Noble Perfecto/cia.png
# Processed: content/train_data/image_25_Noble Perfecto/labrar.png
# Processed: content/train_data/image_25_Noble Perfecto/excelentes.png
# Processed: content/train_data/image_25_Noble Perfecto/y.png
# Processed: content/train_data/image_25_Noble Perfecto/el.png
# Processed: content/train_data/image_25_Noble Perfecto/trabajo.png
# Processed: content/train_data/image_25_Noble Perfecto/sin.png
# Processed: content/train_data/image_25_Noble Perfecto/den.png
# Processed: content/train_data/image_25_Noble Perfecto/seguir.png
# Processed: content/train_data/image_25_Noble Perfecto/cosa.png
# Processed: content/train_data/image_25_Noble Perfecto/de.png
# Processed: content/train_data/image_25_Noble Perfecto/valor:.png
# Processed: content/train_data/image_25_Noble Perfecto/os.png
# Processed: content/train_data/image_25_Noble Perfecto/sangre.png
# Processed: content/train_data/image_25_Noble Perfecto/END.png
# Processed: content/train_data/image_25_Noble Perfecto/OF.png
# Processed: content/train_data/image_25_Noble Perfecto/EXTRACT.png
#
# --- Summary ---
# Total images found       : 2578
# Successfully processed   : 2578
# Skipped due to errors    : 0

# %% [markdown]
# ### Download the manually corrected Training Data
# For both books, combined

# %%
import zipfile
from pathlib import Path
# !gdown --folder https://drive.google.com/drive/folders/1pR0X8FoBNdVtzjyP1_8GbsOO8VeBfqdJ --quiet

zip_path = Path("CorrectedData/outputCorrected.zip")

if zip_path.exists():
    extract_to = zip_path.stem  
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    print(f"Extracted to: {Path(extract_to).resolve()}")
else:
    print(f"Zip file not found: {zip_path}")
# Out:
# Extracted to: /home/scs_deal_projects_notapebackup/user/kemeter/DeepLearnHackathon/NLPRenaissanceChallenge/outputCorrected

# %% [markdown]
# ### Creates a CSV file listing all files in a specified folder, with columns for the filename and its identity (it's name without extension).

# %%
from utils import create_csv_from_folder

create_csv_from_folder("outputCorrected/", "content/train.csv")
create_csv_from_folder("content/test_data/", "content/test.csv")
# Out:
# CSV created at content/train.csv with 4171 entries.
# CSV created at content/test.csv with 165 entries.

# %% [markdown]
# ### Splitting train and test dataset to create a validation dataset

# %%
import pandas as pd

# Load full training CSV
df = pd.read_csv("content/train.csv")

# Split into train and validation (e.g., 80/20 train, rest valid)
df_train = df.iloc[:3200]
df_valid = df.iloc[3200:]

# Optional: Load test data
df_test = pd.read_csv("content/test.csv")

# %%
df_train.to_csv('content/train.csv', index=False)
df_train.head()
# Out:
#                                        FILENAME IDENTITY
# 0     outputCorrected/outputCorrected/(para.png     para
# 1      outputCorrected/outputCorrected/(por.png      por
# 2  outputCorrected/outputCorrected/(que (2).png      que
# 3      outputCorrected/outputCorrected/(que.png      que
# 4        outputCorrected/outputCorrected/13.png       13

# %%
df_valid.to_csv('content/valid.csv', index=False)
df_valid.head()
# Out:
#                                           FILENAME IDENTITY
# 3200  outputCorrected/outputCorrected/que (46).png      que
# 3201  outputCorrected/outputCorrected/que (47).png      que
# 3202  outputCorrected/outputCorrected/que (48).png      que
# 3203  outputCorrected/outputCorrected/que (49).png      que
# 3204   outputCorrected/outputCorrected/que (5).png      que

# %% [markdown]
# ### Sets up configuration parameters and file paths for training, validating, and testing an OCR model.
# Including image size, batch size, number of epochs, model name, callbacks, learning rate, random seeds, dataset file paths, data sizes, and prefetching settings.

# %%
# Image Size
IMG_WIDTH = 200
IMG_HEIGHT = 50
IMAGE_SIZE = (IMG_WIDTH, IMG_HEIGHT)

# Batch Size
BATCH_SIZE = 16

# EPOCHS
EPOCHS = 200

# Model Name
MODEL_NAME = 'SpanishOCR'

# Callbacks
CALLBACKS = [
    callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    callbacks.ModelCheckpoint(filepath=MODEL_NAME + ".h5", save_best_only=True)
]

# Learning Rate
LEARNING_RATE = 1e-3

# Random Seed
np.random.seed(2569)
tf.random.set_seed(2569)

# File Paths
train_csv_path = 'content/train.csv'
valid_csv_path = 'content/valid.csv'
test_csv_path = 'content/test.csv'

train_image_dir = 'content/train_data/'
valid_image_dir = 'content/output'
test_image_dir = 'content/test_data'

# Data Size
TRAIN_SIZE = BATCH_SIZE * 1000
VALID_SIZE = BATCH_SIZE * 500
TEST_SIZE  = BATCH_SIZE * 100

# AUTOTUNE
AUTOTUNE = tfd.AUTOTUNE

# %%
# Train CSV
train_csv = pd.read_csv(train_csv_path)[:TRAIN_SIZE]

# Validation CSV
valid_csv = pd.read_csv(valid_csv_path)[:VALID_SIZE]

# Test CSV
test_csv = pd.read_csv(test_csv_path)[:TEST_SIZE]

# %%
# In order to convert int to string to prevent tf error
test_csv['IDENTITY'] = test_csv['IDENTITY'].apply(lambda x: str(x))

# %%
combo_csv = pd.read_csv("content/train.csv")
labels = [str(word) for word in combo_csv['IDENTITY'].to_numpy()]
labels[:10]
# Out:
# ['para', 'por', 'que', 'que', '13', '14', '20', '6', '8', 'A']

# %% [markdown]
# ### Extracts unique characters from the dataset labels
# Calculates the total number of unique characters, and prints both the count and the set of unique characters

# %%
# Unique characters
unique_chars = set(char for word in labels for char in word)
n_classes = len(unique_chars)

# Show
print(f"Total number of unique characters : {n_classes}")
print(f"Unique Characters : \n{unique_chars}")
# Out:
# Total number of unique characters : 59
# Unique Characters :
# {'4', '\xad', 'v', 'R', 'ñ', 'D', 'I', 'T', '©', 'q', 'e', 'h', 'c', '1', 'p', 'H', 'P', 's', 'K', '2', '6', 'S', 'X', 'ó', 'm', 't', 'L', 'E', 'i', 'b', 'g', 'd', 'U', 'A', 'á', 'Ã', 'z', 'u', '3', 'o', 'r', 'n', 'a', '0', 'O', 'B', '8', 'C', 'f', 'j', 'l', '±', 'y', 'N', 'M', 'G', ' ', 'F', 'x'}

# %%
MAX_LABEL_LENGTH = max(map(len, labels))
print(f"Maximum length of a label : {MAX_LABEL_LENGTH}")
# Out:
# Maximum length of a label : 16

# %% [markdown]
# ### Creates two dictionaries:
# - One that maps unique characters to numeric values using StringLookup.
# - Another that reverses this mapping, converting numeric values back to characters.

# %%
# Character to numeric value dictionary
char_to_num = layers.StringLookup(
    vocabulary = list(unique_chars),
    mask_token = None
)

# Reverse dictionary
num_to_char = layers.StringLookup(
    vocabulary = char_to_num.get_vocabulary(),
    mask_token = None,
    invert = True
)
# Out:
# 2025-07-13 23:10:14.602841: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-07-13 23:10:14.674677: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Loads an image from a given path, decodes it as a JPEG, converts it to a tensor, resizes and normalizes it, and then returns the processed image as a tensor.

# %%
def load_image(image_path : str):
    '''
    This function loads and preprocesses images. It first receives the image path, which is used to
    decode the image as a JPEG using TensorFlow. Then, it converts the image to a tensor and applies
    two processing functions: resizing and normalization. The processed image is then returned by
    the function.

    Argument :
        image_path : The path of the image file to be loaded.

    Return:
        image : The loaded image as a tensor.
    '''

    # Read the Image
    image = tf.io.read_file(image_path)

    # Decode the image
    decoded_image = tf.image.decode_jpeg(image)

    # Convert image data type.
    cnvt_image = tf.image.convert_image_dtype(decoded_image, dtype=tf.float32)

    # Resize the image
    resized_image = tf.image.resize(images = cnvt_image, size = (IMG_HEIGHT, IMG_WIDTH))

    # Transpose
    image = tf.transpose(resized_image, perm = [1, 0, 2])

    # Convert image to a tensor.
    image = tf.cast(image, dtype = tf.float32)

    # Return loaded image
    return image

# %% [markdown]
# ### Loads and preprocesses an image, converts a given label string into a sequence of numeric values, pads the numeric sequence to a fixed length, and returns a dictionary containing the processed image tensor and the label tensor.

# %%
PAD_VALUE = len(char_to_num.get_vocabulary())

def encode_single_sample(image_path : str, label : str):

    '''
    The function takes an image path and label as input and returns a dictionary containing the processed image tensor and the label tensor.
    First, it loads the image using the load_image function, which decodes and resizes the image to a specific size. Then it converts the given
    label string into a sequence of Unicode characters using the unicode_split function. Next, it uses the char_to_num layer to convert each
    character in the label to a numerical representation. It pads the numerical representation with a special class (n_classes)
    to ensure that all labels have the same length (MAX_LABEL_LENGTH). Finally, it returns a dictionary containing the processed image tensor
    and the label tensor.

    Arguments :
        image_path : The location of the image file.
        label      : The text to present in the image.

    Returns:
        dict : A dictionary containing the processed image and label.
    '''

    # Get the image
    image = load_image(image_path)

    # Convert the label into characters
    chars = tf.strings.unicode_split(label, input_encoding='UTF-8')

    # Convert the characters into vectors
    vecs = char_to_num(chars)
    vecs = vecs[:MAX_LABEL_LENGTH]
    # Pad label
    pad_size = tf.maximum(MAX_LABEL_LENGTH - tf.shape(vecs)[0], 0)
    vecs = tf.pad(vecs, paddings=[[0, pad_size]], constant_values=PAD_VALUE)

    return {'image': image, 'label': vecs}

# %% [markdown]
# ### Splits the combined dataset into training and validation subsets, shuffles the data, and then creates batched and prefetched TensorFlow datasets for efficient data loading during model training.

# %%
# Further split the training dataset into training and validation subsets
train_size = 3200  # 80% of the training data for training
val_size = len(combo_csv) - train_size  # Remaining 20% for validation

# Splitting the training dataset
train_ds = tf.data.Dataset.from_tensor_slices(
    (np.array(combo_csv['FILENAME'].to_list()), np.array(combo_csv['IDENTITY'].to_list()))
).shuffle(3200)

# Create training dataset
train_ds = train_ds.take(train_size).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# Create validation dataset
valid_ds = train_ds.skip(train_size).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %%
# #TODO: why do we have this if we overwrite train_ds in the next cell?

# %% [markdown]
# ### Creates TensorFlow datasets for training, validation, and testing.
# - Loading image paths and labels
# - Shuffling the training data
# - Applying the encode_single_sample function to preprocess the images and labels
# - Batching the data
# - Using prefetching for optimized data loading.

# %%
from pathlib import Path

# Helper to join full path for filenames
def get_full_paths(df):
    full_paths = df['FILENAME'].astype(str).tolist()  # Don't prepend anything
    labels = df['IDENTITY'].astype(str).tolist()
    return np.array(full_paths), np.array(labels)

# Prepare data
train_X, train_y = get_full_paths(train_csv)
valid_X, valid_y = get_full_paths(valid_csv)
test_X, test_y   = get_full_paths(test_csv)

# Create datasets
train_ds = tf.data.Dataset.from_tensor_slices((train_X, train_y)) \
    .shuffle(3200) \
    .map(encode_single_sample, num_parallel_calls=AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(AUTOTUNE)

valid_ds = tf.data.Dataset.from_tensor_slices((valid_X, valid_y)) \
    .map(encode_single_sample, num_parallel_calls=AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((test_X, test_y)) \
    .map(encode_single_sample, num_parallel_calls=AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(AUTOTUNE)

# %%
print(f"Training Data Size   : {tf.data.Dataset.cardinality(train_ds).numpy() * BATCH_SIZE}")
print(f"Validation Data Size : {tf.data.Dataset.cardinality(valid_ds).numpy() * BATCH_SIZE}")
print(f"Testing Data Size    : {tf.data.Dataset.cardinality(test_ds).numpy() * BATCH_SIZE}")
# Out:
# Training Data Size   : 3200
# Validation Data Size : 976
# Testing Data Size    : 176

# %% [markdown]
# ### Displays a grid of images with their true labels, and optionally their predicted labels if a model is provided, using Matplotlib for visualization.

# %%
def show_images(data, GRID=[4,4], FIGSIZE=(25, 8), cmap='binary_r', model=None, decode_pred=None):

    # Plotting configurations
    plt.figure(figsize=FIGSIZE)
    n_rows, n_cols = GRID

    # Loading Data
    data = next(iter(data))
    images, labels = data['image'], data['label']

    # Iterate over the data
    for index, (image, label) in enumerate(zip(images, labels)):

        # Label processing
        text_label = num_to_char(label)
        text_label = tf.strings.reduce_join(text_label).numpy().decode('UTF-8')
        text_label = text_label.replace("[UNK]", " ").strip()

        # Create a sub plot
        plt.subplot(n_rows, n_cols, index+1)
        plt.imshow(tf.transpose(image, perm=[1,0,2]), cmap=cmap)
        plt.axis('off')

        if model is not None and decode_pred is not None:
            # Make prediction
            pred = model.predict(tf.expand_dims(image, axis=0))
            pred = decode_pred(pred)[0]
            title = f"True : {text_label}\nPred : {pred}"
            plt.title(title)
        else:
            # add title
            plt.title(text_label)

    # Show the final plot
    cls()
    plt.show()

# %%
show_images(data=train_ds, cmap='gray')

# %% [markdown]
# # **Model Definition**

# %% [markdown]
# ### Defines a custom Keras layer that computes and adds the Connectionist Temporal Classification (CTC) loss to the model for training sequence-to-sequence prediction tasks.

# %%
class CTCLayer(layers.Layer):

    def __init__(self, **kwargs) -> None:
        super().__init__(**kwargs)

        self.loss_fn = keras.backend.ctc_batch_cost

    def call(self, y_true, y_pred):

        batch_len = tf.cast(tf.shape(y_true)[0], dtype='int64')

        input_len = tf.cast(tf.shape(y_pred)[1], dtype='int64') * tf.ones(shape=(batch_len, 1), dtype='int64')
        label_len = tf.cast(tf.shape(y_true)[1], dtype='int64') * tf.ones(shape=(batch_len, 1), dtype='int64')

        loss = self.loss_fn(y_true, y_pred, input_len, label_len)

        self.add_loss(loss)

        return y_pred

# %% [markdown]
# ### Decodes the predicted labels from the OCR model, converting numeric values back to characters and removing unknown tokens to produce the final text output.

# %%
def decode_pred(pred_label):

    '''
    The decode_pred function is used to decode the predicted labels generated by the OCR model.
    It takes a matrix of predicted labels as input, where each time step represents the probability
    for each character. The function uses CTC decoding to decode the numeric labels back into their
    character values. The function also removes any unknown tokens and returns the decoded texts as a
    list of strings. The function utilizes the num_to_char function to map numeric values back to their
    corresponding characters. Overall, the function is an essential step in the OCR process, as it allows
    us to obtain the final text output from the model's predictions.

    Argument :
        pred_label : These are the model predictions which are needed to be decoded.

    Return:
        filtered_text : This is the list of all the decoded and processed predictions.

    '''

    # Input length
    input_len = np.ones(shape=pred_label.shape[0]) * pred_label.shape[1]

    # CTC decode
    decode = keras.backend.ctc_decode(pred_label, input_length=input_len, greedy=True)[0][0][:,:MAX_LABEL_LENGTH] #TODO: is greedy good here? maybe use other option

    # Converting numerics back to their character values
    chars = num_to_char(decode)

    # Join all the characters
    texts = [tf.strings.reduce_join(inputs=char).numpy().decode('UTF-8') for char in chars]

    # Remove the unknown token
    filtered_texts = [text.replace('[UNK]', " ").strip() for text in texts]

    return filtered_texts

# %% [markdown]
# ### This code defines a deep learning model for optical character recognition (OCR) using a combination of convolutional neural networks (CNNs) for feature extraction and bidirectional long short-term memory (LSTM) networks for sequence learning, concluding with a custom CTC loss layer for training.

# %%
# Input Layer
input_images = layers.Input(shape=(IMG_WIDTH, IMG_HEIGHT, 1), name="image")

# Labels : These are added for the training purpose.
target_labels = layers.Input(shape=(None, ), name="label")

# CNN Network
x = layers.Conv2D(
    filters=32,
    kernel_size=3,
    strides=1,
    padding='same',
    activation='relu',
    kernel_initializer='he_normal'
)(input_images)

x = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(x)

x = layers.Conv2D(
    filters=64,
    kernel_size=3,
    strides=1,
    padding='same',
    activation='relu',
    kernel_initializer='he_normal'
)(x)

x = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(x)
# x.shape = (None, 50, 12, 64)

# Encoding Space
#encoding = layers.Reshape(target_shape=((IMG_WIDTH//4), (IMG_HEIGHT//4)*64))(x)
encoding = layers.Reshape(target_shape=(x.shape[1], x.shape[2] * x.shape[3]))(x) #(None, 50, 768) 
encoding = layers.Dense(64, activation='relu', kernel_initializer='he_normal')(encoding)
encoding = layers.Dropout(0.2)(encoding) #(None, 50, 64)

# RNN Network
x = layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.25))(encoding)
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.25))(x)

# Output Layer
output = layers.Dense(len(char_to_num.get_vocabulary())+1, activation='softmax')(x)

# CTC Layer
ctc_layer = CTCLayer()(target_labels, output)

# Model
ocr_model = keras.Model(
    inputs=[input_images, target_labels],
    outputs=[ctc_layer]
)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
# Model Summary
ocr_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  image (InputLayer)          [(None, 200, 50, 1)]         0         []
#
#  conv2d (Conv2D)             (None, 200, 50, 32)          320       ['image[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 100, 25, 32)          0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 100, 25, 64)          18496     ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 50, 12, 64)           0         ['conv2d_1[0][0]']
#  g2D)
#
#  reshape (Reshape)           (None, 50, 768)              0         ['max_pooling2d_1[0][0]']
#
#  dense (Dense)               (None, 50, 64)               49216     ['reshape[0][0]']
#
#  dropout (Dropout)           (None, 50, 64)               0         ['dense[0][0]']
#
#  bidirectional (Bidirection  (None, 50, 256)              197632    ['dropout[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 50, 128)              164352    ['bidirectional[0][0]']
#  onal)
#
#  label (InputLayer)          [(None, None)]               0         []
#
#  dense_1 (Dense)             (None, 50, 61)               7869      ['bidirectional_1[0][0]']
#
#  ctc_layer (CTCLayer)        (None, 50, 61)               0         ['label[0][0]',
#                                                                      'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 437885 (1.67 MB)
# Trainable params: 437885 (1.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(ocr_model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ### Compiles the OCR model with the Adam optimizer and trains it on the training dataset with validation, using early stopping and model checkpoint callbacks.

# %%
# Compile
ocr_model.compile(optimizer='adam')

# Train
history = ocr_model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=EPOCHS,
    callbacks=CALLBACKS
)
# Out:
# Epoch 1/200
# 200/200 [==============================] - 16s 64ms/step - loss: 24.5891 - val_loss: 16.5892
# Epoch 2/200
# /home/scs_deal_learning/miniconda_env/envs/deeplearn_env/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 12s 60ms/step - loss: 16.2434 - val_loss: 16.7087
# Epoch 3/200
# 200/200 [==============================] - 13s 63ms/step - loss: 15.7775 - val_loss: 17.0177
# Epoch 4/200
# 200/200 [==============================] - 12s 62ms/step - loss: 15.4038 - val_loss: 17.2947
# Epoch 5/200
# 200/200 [==============================] - 13s 63ms/step - loss: 14.9412 - val_loss: 17.1866
# Epoch 6/200
# 200/200 [==============================] - 12s 62ms/step - loss: 14.2850 - val_loss: 16.6292
# Epoch 7/200
# 200/200 [==============================] - 13s 63ms/step - loss: 12.9022 - val_loss: 14.9496
# Epoch 8/200
# 200/200 [==============================] - 13s 65ms/step - loss: 9.8920 - val_loss: 12.3489
# Epoch 9/200
# 200/200 [==============================] - 13s 63ms/step - loss: 6.8147 - val_loss: 10.5814
# Epoch 10/200
# 200/200 [==============================] - 13s 63ms/step - loss: 5.0367 - val_loss: 9.8321
# Epoch 11/200
# 200/200 [==============================] - 13s 63ms/step - loss: 4.1203 - val_loss: 9.9230
# Epoch 12/200
# 200/200 [==============================] - 13s 63ms/step - loss: 3.5465 - val_loss: 9.1513
# Epoch 13/200
# 200/200 [==============================] - 12s 63ms/step - loss: 3.1813 - val_loss: 9.5219
# Epoch 14/200
# 200/200 [==============================] - 12s 62ms/step - loss: 2.8630 - val_loss: 9.2948
# Epoch 15/200
# 200/200 [==============================] - 12s 62ms/step - loss: 2.7377 - val_loss: 9.8489
# Epoch 16/200
# 200/200 [==============================] - 13s 63ms/step - loss: 2.5613 - val_loss: 9.1437
# Epoch 17/200
# 200/200 [==============================] - 12s 62ms/step - loss: 2.3733 - val_loss: 9.6011
# Epoch 18/200
# 200/200 [==============================] - 12s 62ms/step - loss: 2.2411 - val_loss: 9.4059
# Epoch 19/200
# 200/200 [==============================] - 12s 62ms/step - loss: 2.1303 - val_loss: 9.4136
# Epoch 20/200
# 200/200 [==============================] - 13s 63ms/step - loss: 2.0748 - val_loss: 9.3881
# Epoch 21/200
# 200/200 [==============================] - 12s 62ms/step - loss: 1.9543 - val_loss: 9.4411
# Epoch 22/200
# 200/200 [==============================] - 12s 62ms/step - loss: 1.9109 - val_loss: 9.5723
# Epoch 23/200
# 200/200 [==============================] - 12s 62ms/step - loss: 1.8295 - val_loss: 9.9000
# Epoch 24/200
# 200/200 [==============================] - 12s 62ms/step - loss: 1.7701 - val_loss: 9.5763
# Epoch 25/200
# 200/200 [==============================] - 12s 62ms/step - loss: 1.6597 - val_loss: 9.5521
# Epoch 26/200
# 200/200 [==============================] - 13s 63ms/step - loss: 1.6289 - val_loss: 9.6538

# %% [markdown]
# ### Creates an inference model from the trained OCR model for making predictions and prints the model summary.

# %%
# Model required for inference
inference_model = keras.Model(
    inputs=ocr_model.get_layer(name="image").input,
    #outputs=ocr_model.get_layer(name='dense_6').output
    outputs=ocr_model.get_layer(name='dense_1').output
)

# Model summary
inference_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  image (InputLayer)          [(None, 200, 50, 1)]      0
#
#  conv2d (Conv2D)             (None, 200, 50, 32)       320
#
#  max_pooling2d (MaxPooling2  (None, 100, 25, 32)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 100, 25, 64)       18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 50, 12, 64)        0
#  g2D)
#
#  reshape (Reshape)           (None, 50, 768)           0
#
#  dense (Dense)               (None, 50, 64)            49216
#
#  dropout (Dropout)           (None, 50, 64)            0
#
#  bidirectional (Bidirection  (None, 50, 256)           197632
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 50, 128)           164352
#  onal)
#
#  dense_1 (Dense)             (None, 50, 61)            7869
#
# =================================================================
# Total params: 437885 (1.67 MB)
# Trainable params: 437885 (1.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.config.experimental.enable_op_determinism()  # sometimes helps

# Disable fused grouped conv (if available)
tf.config.experimental.set_memory_growth(tf.config.list_physical_devices('GPU')[0], True)

print(decode_pred(inference_model.predict(test_ds))[:10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 4
#       1 tf.config.experimental.enable_op_determinism()  # sometimes helps
#       3 # Disable fused grouped conv (if available)
# ----> 4 tf.config.experimental.set_memory_growth(tf.config.list_physical_devices('GPU')[0], True)
#       6 print(decode_pred(inference_model.predict(test_ds))[:10])
#
# IndexError: list index out of range

# %%
import os
print(os.environ.get('LD_LIBRARY_PATH'))
# Out:
# /home/scs_deal_learning/miniconda_env/envs/deeplearn_env/lib/python3.8/site-packages/cv2/../../lib64:

# %%
show_images(data=valid_ds, model=inference_model, decode_pred=decode_pred, cmap='binary')

# %% [markdown]
# ### Generates and decodes predictions from the inference model on the test dataset, printing the results in groups of 8 words per line.

# %%
decoded_predictions = decode_pred(inference_model.predict(test_ds))

# Print decoded predictions in groups of 8 words per line (You will have to figure out a better and ideal approach, this is just for sample)
words_per_line = 8
for i in range(0, int(len(decoded_predictions)/10), words_per_line):
    print(' '.join(decoded_predictions[i:i+words_per_line]))

# %% [markdown]
# ## Contributors
# - Shashank Shekhar Singh (Indian Institue of Technology, BHU)
# - Kate O'Reilly (Trinity College Dublin)
# - Utsav Rai (Imperial College London)
# - Yukinori Yamamoto (Waseda University)
# - Saarthak Gupta (Indian Institute of Technology BHU)
# - Pranav Kulkarni (Indinan Institute of Technology, Bombay)
# - Arsh Khan (VJTI, Mumbai)
# - Xabier Granja (University of Alabama)
# - Sergei Gleyzer (University of Alabama)
# - Harrison Meadows (University of Tennessee)
